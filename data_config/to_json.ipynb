# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
college_park_coords = (38.9897, -76.9378)  # (lat, lon)

# %%
from datetime import datetime

# Helper to convert "9am-5pm" -> "09:00", "17:00"
def parse_hours(hour_str):
    open_raw, close_raw = hour_str.split('-')
    open_time = datetime.strptime(open_raw.strip(), '%I%p').strftime('%H:%M')
    close_time = datetime.strptime(close_raw.strip(), '%I%p').strftime('%H:%M')
    return open_time, close_time

# %%
# Function to compute simple spherical distance
def haversine(lat1, lon1, lat2, lon2):
    R = 3958.8  # Earth radius in miles
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return 2 * R * np.arcsin(np.sqrt(a))

# %%
df = pd.read_csv('./datasets/Food_Pantries_wGeo.csv')

df.head(20)
# Out:
#                             Name               StreetAddress       City State  \
# 0               Abundant Life II  5110 Balto Natt Pike apt 4  Baltimore    MD
# 1               Adams Chapel AME            3813 Egerton Rd.  Baltimore    MD
# 2                    Agape House      222 N. Carrollton Ave.  Baltimore    MD
# 3              AMES Memorial AME               615 Baker St.  Baltimore    MD
# 4               Bernard E. Mason        2121 Windsor Gardens  Baltimore    MD
# 5         Bethany Baptist Church           2616 Ridgeley St.  Baltimore    MD
# 6           Bethel Church of God          301 W. 28th Street  Baltimore    MD
# 7      Carter Memorial Emergency        745 West Fayette St.  Baltimore    MD
# 8         Central Baptist Church      2035 West Baltimore St  Baltimore    MD
# 9                    Chase House           1027 Cathedral St  Baltimore    MD
# 10     Christ Deliverance Church             711 Walnut Ave.  Baltimore    MD
# 11     Christian Memorial Church        2001 West North Ave.  Baltimore    MD
# 12        Church Of Jesus Christ            2880 Hillen Road  Baltimore    MD
# 13               Claremont Homes               4312 Clareway  Baltimore    MD
# 14             Collington Square          1211 N. Chester St  Baltimore    MD
# 15        Concord Baptist Church   5204 Liberty Heights Ave.  Baltimore    MD
# 16                Corpus Christi           703 Whitelock St.  Baltimore    MD
# 17             Deliverance Manna          3538 Old York Road  Baltimore    MD
# 18  Dept of Housing Neighborhood               22 S. Calhoun  Baltimore    MD
# 19    Donald Bentley Food Pantry       2405 Loch Raven Blvd.  Baltimore    MD
#
#     ZipCode               Contact           Phone       StandardHours  Monday  \
# 0     21229           Thomas Hill  (410) 947-6343            9am-12pm       1
# 1     21215         Arlean Burton  (410) 542-6200            11am-1pm       0
# 2     21223         Rev. Robinson  (410) 728-2222            12pm-6pm       0
# 3     21211    Jacqueline Johnson  (410) 523-5556            11am-1pm       0
# 4     21207        Liflie Ziegler  (410) 448-1311            11am-4pm       0
# 5     21230           Sanra White  (410) 539-5029            9am-12pm       1
# 6     21211    Charletta Williams  (410) 235-0160  9am-12pm, 12pm-3pm       0
# 7     21201          Verner Lewis  (410) 752-6123            10am-2pm       0
# 8     21223  Rev. Matthew Braxton  (410) 233-8558            12pm-2pm       0
# 9     21201           Joan Weston  (410) 539-6155            10am-2pm       0
# 10    21229    Rev. Martin Jacobs  (410) 945-8700            12pm-6pm       1
# 11    21217        Barbara Grimes  (410) 728-0464           10am-12pm       0
# 12    21218          James Gamble  (410) 366-8010            10am-3pm       1
# 13    21213           Anna Warren  (410) 485-4836            10am-2pm       1
# 14    21213      Gloria Etheridge  (410) 342-6740           12pm-4:30       0
# 15    21207            Hazel Guin  (410) 367-1117        10am-11:30am       0
# 16    21217               Mariano  (410) 523-5822          1:30pm-3pm       0
# 17    21218         Jerry Wallace  (410) 947-4536  6pm-8pm, 10am-12pm       0
# 18    21223                Deinia  (410) 566-6658            10am-3pm       1
# 19    21218         Ellen Bentley  (410) 662-9287         9am-12:30pm       0
#
#     Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday  ServiceTypes  \
# 0         0          0         0       0         0       0           NaN
# 1         0          1         0       0         1       0           NaN
# 2         0          1         0       0         1       0           NaN
# 3         1          0         0       0         0       0           NaN
# 4         0          0         1       0         0       0           NaN
# 5         1          1         1       1         0       0           NaN
# 6         0          0         0       1         0       1           NaN
# 7         0          0         1       0         0       0           NaN
# 8         0          0         0       0         1       0           NaN
# 9         0          0         0       1         0       0           NaN
# 10        0          1         0       1         1       0           NaN
# 11        0          0         0       0         1       0           NaN
# 12        0          0         1       0         0       0           NaN
# 13        0          1         0       1         0       0           NaN
# 14        0          1         0       0         0       0           NaN
# 15        0          0         0       0         1       0           NaN
# 16        0          0         1       0         0       0           NaN
# 17        0          0         1       0         1       0           NaN
# 18        0          0         0       0         0       0           NaN
# 19        0          0         0       0         1       0           NaN
#
#     Requirements  Languages  Accessibility  Latitude  Longitude  \
# 0            NaN        NaN            NaN   39.2866   -76.7007
# 1            NaN        NaN            NaN   39.3337   -76.6897
# 2            NaN        NaN            NaN   39.2912   -76.6447
# 3            NaN        NaN            NaN   39.3086   -76.6334
# 4            NaN        NaN            NaN   39.3153   -76.6932
# 5            NaN        NaN            NaN   39.2735   -76.6562
# 6            NaN        NaN            NaN   39.3214   -76.6219
# 7            NaN        NaN            NaN   39.2904   -76.6278
# 8            NaN        NaN            NaN   39.2870   -76.6447
# 9            NaN        NaN            NaN   39.3002   -76.6166
# 10           NaN        NaN            NaN   39.2865   -76.6919
# 11           NaN        NaN            NaN   39.3093   -76.6447
# 12           NaN        NaN            NaN   39.3235   -76.5897
# 13           NaN        NaN            NaN   39.3018   -76.5671
# 14           NaN        NaN            NaN   39.3046   -76.5826
# 15           NaN        NaN            NaN   39.3318   -76.6947
# 16           NaN        NaN            NaN   39.3137   -76.6335
# 17           NaN        NaN            NaN   39.3287   -76.6096
# 18           NaN        NaN            NaN   39.2878   -76.6447
# 19           NaN        NaN            NaN   39.3187   -76.5901
#
#                 Notes
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15  4th Saturday only
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN

# %%
names = df['Name']
description = df['Notes'].fillna('')
address = df['StreetAddress']
latitude = df['Latitude']
longitude = df['Longitude']
contactPhone = df['Phone']
contactEmail = df['Contact']
imageUrl = pd.Series([''] * len(names), name = 'imageUrl')
adminId = df['Contact']
walkingDistance = df.apply(
    lambda row: haversine(college_park_coords[0], college_park_coords[1], row['Latitude'], row['Longitude']),
    axis=1
)
offersDelivery = df['ServiceTypes'].fillna('')
specialNotes = df['Notes'].fillna('')

# %%
def parse_time(s):
    s = s.strip().lower()
    if 'am' in s or 'pm' in s:
        fmt = '%I:%M%p' if ':' in s else '%I%p'
    else:
        fmt = '%H:%M' if ':' in s else '%H'
    return datetime.strptime(s, fmt)


def parse_hours(hour_str):
    # Split on commas to separate multiple time ranges
    ranges = hour_str.split(',')
    times = []

    for time_range in ranges:
        open_raw, close_raw = time_range.strip().split('-')
        open_time = parse_time(open_raw)
        close_time = parse_time(close_raw)
        times.append((open_time, close_time))

    earliest_open = min(t[0] for t in times).strftime('%H:%M')
    latest_close = max(t[1] for t in times).strftime('%H:%M')

    return earliest_open, latest_close



# Days of week
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Result dictionary: {store name → day-by-day DataFrame}
openingHours = {}

for _, row in df.iterrows():
    name = row['Name']
    open_time, close_time = parse_hours(row['StandardHours'])

    # Filter only days where store is open
    open_days = [day for day in days if row[day] == 1]

    store_df = pd.DataFrame({
        'open': open_time,
        'close': close_time
    }, index=open_days)

    openingHours[name] = store_df

# %%
openingHours
# Out:
# {'Abundant Life II':          open  close
#  Monday  09:00  12:00,
#  'Adams Chapel AME':             open  close
#  Wednesday  11:00  13:00
#  Saturday   11:00  13:00,
#  'Agape House':             open  close
#  Wednesday  12:00  18:00
#  Saturday   12:00  18:00,
#  'AMES Memorial AME':           open  close
#  Tuesday  11:00  13:00,
#  'Bernard E. Mason':            open  close
#  Thursday  11:00  16:00,
#  'Bethany Baptist Church':             open  close
#  Monday     09:00  12:00
#  Tuesday    09:00  12:00
#  Wednesday  09:00  12:00
#  Thursday   09:00  12:00
#  Friday     09:00  12:00,
#  'Bethel Church of God':          open  close
#  Friday  09:00  15:00
#  Sunday  09:00  15:00,
#  'Carter Memorial Emergency':            open  close
#  Thursday  10:00  14:00,
#  'Central Baptist Church':            open  close
#  Saturday  12:00  14:00,
#  'Chase House':          open  close
#  Friday  10:00  14:00,
#  'Christ Deliverance Church':             open  close
#  Monday     12:00  18:00
#  Wednesday  12:00  18:00
#  Friday     12:00  18:00
#  Saturday   12:00  18:00,
#  'Christian Memorial Church':            open  close
#  Saturday  10:00  12:00,
#  'Church Of Jesus Christ':            open  close
#  Monday    10:00  15:00
#  Thursday  10:00  15:00,
#  'Claremont Homes':             open  close
#  Monday     10:00  14:00
#  Wednesday  10:00  14:00
#  Friday     10:00  14:00,
#  'Collington Square':             open  close
#  Wednesday  12:00  04:30,
#  'Concord Baptist Church':            open  close
#  Saturday  10:00  11:30,
#  'Corpus Christi':            open  close
#  Thursday  13:30  15:00,
#  'Deliverance Manna':            open  close
#  Thursday  10:00  20:00
#  Saturday  10:00  20:00,
#  'Dept of Housing Neighborhood':          open  close
#  Monday  10:00  15:00,
#  'Donald Bentley Food Pantry':            open  close
#  Saturday  09:00  12:30,
#  'Dukeland Development':          open  close
#  Monday  12:00  20:00
#  Friday  12:00  20:00,
#  'East Baltimore Church of God':            open  close
#  Saturday  10:00  15:00
#  Sunday    10:00  15:00,
#  'Emergency Food Relief Fund':             open  close
#  Wednesday  11:30  13:00,
#  'First Apostolic Faith Church':            open  close
#  Saturday  14:30  16:30,
#  'First Charity Baptist Church':            open  close
#  Monday    10:00  14:00
#  Thursday  10:00  14:00,
#  'Pleasant View Gardens':          open  close
#  Friday  10:00  14:00,
#  'Poppleton Co-op':             open  close
#  Monday     11:00  15:00
#  Tuesday    11:00  15:00
#  Wednesday  11:00  15:00
#  Thursday   11:00  15:00
#  Friday     11:00  15:00,
#  'Prisoners Aid':             open  close
#  Wednesday  10:00  18:00,
#  'Quality of Life Corp':            open  close
#  Monday    10:00  14:00
#  Thursday  10:00  14:00,
#  'Ray of Hope':           open  close
#  Tuesday  10:00  14:00,
#  'Refuge Way of Cross Church':             open  close
#  Wednesday  12:00  14:00,
#  'Royal Light Outreach':            open  close
#  Tuesday   11:00  13:00
#  Thursday  11:00  13:00,
#  'Salvation Army':             open  close
#  Monday     08:30  12:00
#  Tuesday    08:30  12:00
#  Wednesday  08:30  12:00
#  Thursday   08:30  12:00
#  Friday     08:30  12:00,
#  'Sharon Baptist':            open  close
#  Saturday  10:00  12:00,
#  'Second Shiloh':             open  close
#  Tuesday    11:00  13:00
#  Wednesday  11:00  13:00
#  Thursday   11:00  13:00,
#  'Solomon Temple Baptist Church':             open  close
#  Monday     10:00  14:00
#  Tuesday    10:00  14:00
#  Wednesday  10:00  14:00
#  Thursday   10:00  14:00
#  Friday     10:00  14:00,
#  'Southwest Emergency Food Program':             open  close
#  Tuesday    09:00  15:00
#  Wednesday  09:00  15:00
#  Thursday   09:00  15:00,
#  'South Baltimore Emergency':             open  close
#  Monday     10:00  13:00
#  Tuesday    10:00  13:00
#  Wednesday  10:00  13:00
#  Thursday   10:00  13:00
#  Friday     10:00  13:00,
#  'Southwest Neighborhood Service Center':             open  close
#  Monday     10:00  14:00
#  Wednesday  10:00  14:00
#  Friday     10:00  14:00,
#  'St. Abraham Baptist Church':             open  close
#  Wednesday  09:30  13:00,
#  'St. Ambrose':             open  close
#  Monday     09:00  16:00
#  Tuesday    09:00  16:00
#  Wednesday  09:00  16:00
#  Thursday   09:00  16:00
#  Friday     09:00  16:00,
#  'St. Ann Outreach Ctr.':            open  close
#  Tuesday   08:00  14:00
#  Saturday  08:00  14:00,
#  "St. Bernadine's Catholic":             open  close
#  Tuesday    10:00  12:00
#  Wednesday  10:00  12:00
#  Thursday   10:00  12:00,
#  'St. Cecilia':             open  close
#  Wednesday  10:00  12:00,
#  'St. Elizabeth Food Pantry':           open  close
#  Tuesday  11:30  13:30
#  Friday   11:30  13:30,
#  'St. Gregory the Great':             open  close
#  Monday     10:00  14:00
#  Tuesday    10:00  14:00
#  Wednesday  10:00  14:00
#  Thursday   10:00  14:00
#  Friday     10:00  14:00,
#  'St. Luke Temple':           open  close
#  Tuesday  17:00  21:00
#  Friday   17:00  21:00,
#  "St. Mark's UMC/Bread of Life":             open  close
#  Wednesday  17:30  19:00
#  Friday     17:30  19:00,
#  'St. Michael Outreach':             open  close
#  Tuesday    09:00  12:00
#  Wednesday  09:00  12:00
#  Thursday   09:00  12:00,
#  'St. Paul Baptist Church':            open  close
#  Monday    10:00  19:00
#  Thursday  10:00  19:00,
#  "St. Vincent's Emergency Services":          open  close
#  Monday  12:30  14:00,
#  'St. Wenceslaus':             open  close
#  Wednesday  11:00  13:00
#  Thursday   11:00  13:00,
#  'Temple House':            open  close
#  Tuesday   10:00  12:00
#  Saturday  10:00  12:00,
#  'The Tree of Life Bible Church':           open  close
#  Tuesday  15:00  19:00,
#  'Total Man Outreach':            open  close
#  Saturday  10:00  12:00,
#  'Trinity AME Church':            open  close
#  Thursday  11:00  13:00,
#  'Trinity Apostolic Faith':          open  close
#  Sunday  09:30  12:00}

# %%
df1 = pd.DataFrame({
    'name': names.values,
    'description': description.values,
    'address': address.values,
    'latitude': latitude.values,
    'longitude': longitude.values,
    'contactPhone': contactPhone.values,
    'contactEmail': contactEmail.values,
    'imageUrl': imageUrl.values,
    'adminId': adminId.values,
    'walkingDistance': walkingDistance.values,
    'offersDelivery': offersDelivery.values
})

df1['openingHours'] = df1['name'].map(openingHours)
df1['specialNotes'] = specialNotes

df1
# Out:
#                               name description                     address  \
# 0                 Abundant Life II              5110 Balto Natt Pike apt 4
# 1                 Adams Chapel AME                        3813 Egerton Rd.
# 2                      Agape House                  222 N. Carrollton Ave.
# 3                AMES Memorial AME                           615 Baker St.
# 4                 Bernard E. Mason                    2121 Windsor Gardens
# ..                             ...         ...                         ...
# 106                   Temple House                      812 N. Fulton Ave.
# 107  The Tree of Life Bible Church                    516 N. Schroeder St.
# 108             Total Man Outreach                     1116 N. Gilmore St.
# 109             Trinity AME Church                     2140 E. Hoffman St.
# 110        Trinity Apostolic Faith                     3600 W. Rogers Ave.
#
#      latitude  longitude    contactPhone        contactEmail imageUrl  \
# 0     39.2866   -76.7007  (410) 947-6343         Thomas Hill
# 1     39.3337   -76.6897  (410) 542-6200       Arlean Burton
# 2     39.2912   -76.6447  (410) 728-2222       Rev. Robinson
# 3     39.3086   -76.6334  (410) 523-5556  Jacqueline Johnson
# 4     39.3153   -76.6932  (410) 448-1311      Liflie Ziegler
# ..        ...        ...             ...                 ...      ...
# 106   39.2994   -76.6378  (410) 462-1876      Stanley Butler
# 107   39.2939   -76.6447  (410) 542-1928     Lassiter Basket
# 108   39.3027   -76.6447  (410) 728-8151     Willie Williams
# 109   39.3125   -76.5826  (410) 342-2320     Nancy Woodhouse
# 110   39.3318   -76.6819  (410) 448-1215   Elizabeth Milburn
#
#                 adminId  walkingDistance offersDelivery  \
# 0           Thomas Hill        24.130458
# 1         Arlean Burton        27.232303
# 2         Rev. Robinson        26.089784
# 3    Jacqueline Johnson        27.414150
# 4        Liflie Ziegler        26.036042
# ..                  ...              ...            ...
# 106      Stanley Butler        26.764261
# 107     Lassiter Basket        26.238801
# 108     Willie Williams        26.727757
# 109     Nancy Woodhouse        29.320071
# 110   Elizabeth Milburn        27.325133
#
#                                           openingHours specialNotes
# 0                     open  close
# Monday  09:00  12:00
# 1                open  close
# Wednesday  11:00  13:0...
# 2                open  close
# Wednesday  12:00  18:0...
# 3                    open  close
# Tuesday  11:00  13:00
# 4                   open  close
# Thursday  11:00  16:00
# ..                                                 ...          ...
# 106             open  close
# Tuesday   10:00  12:00
# ...
# 107                  open  close
# Tuesday  15:00  19:00
# 108                 open  close
# Saturday  10:00  12:00
# 109                 open  close
# Thursday  11:00  13:00
# 110                   open  close
# Sunday  09:30  12:00
#
# [111 rows x 13 columns]

# %%
def opening_hours_df_to_dict(df):
    return {
        day.lower(): {'open': row['open'], 'close': row['close']}
        for day, row in df.iterrows()
    }

df1['openingHours'] = df1['openingHours'].apply(opening_hours_df_to_dict)

# %%
df1
# Out:
#                               name description                     address  \
# 0                 Abundant Life II              5110 Balto Natt Pike apt 4
# 1                 Adams Chapel AME                        3813 Egerton Rd.
# 2                      Agape House                  222 N. Carrollton Ave.
# 3                AMES Memorial AME                           615 Baker St.
# 4                 Bernard E. Mason                    2121 Windsor Gardens
# ..                             ...         ...                         ...
# 106                   Temple House                      812 N. Fulton Ave.
# 107  The Tree of Life Bible Church                    516 N. Schroeder St.
# 108             Total Man Outreach                     1116 N. Gilmore St.
# 109             Trinity AME Church                     2140 E. Hoffman St.
# 110        Trinity Apostolic Faith                     3600 W. Rogers Ave.
#
#      latitude  longitude    contactPhone        contactEmail imageUrl  \
# 0     39.2866   -76.7007  (410) 947-6343         Thomas Hill
# 1     39.3337   -76.6897  (410) 542-6200       Arlean Burton
# 2     39.2912   -76.6447  (410) 728-2222       Rev. Robinson
# 3     39.3086   -76.6334  (410) 523-5556  Jacqueline Johnson
# 4     39.3153   -76.6932  (410) 448-1311      Liflie Ziegler
# ..        ...        ...             ...                 ...      ...
# 106   39.2994   -76.6378  (410) 462-1876      Stanley Butler
# 107   39.2939   -76.6447  (410) 542-1928     Lassiter Basket
# 108   39.3027   -76.6447  (410) 728-8151     Willie Williams
# 109   39.3125   -76.5826  (410) 342-2320     Nancy Woodhouse
# 110   39.3318   -76.6819  (410) 448-1215   Elizabeth Milburn
#
#                 adminId  walkingDistance offersDelivery  \
# 0           Thomas Hill        24.130458
# 1         Arlean Burton        27.232303
# 2         Rev. Robinson        26.089784
# 3    Jacqueline Johnson        27.414150
# 4        Liflie Ziegler        26.036042
# ..                  ...              ...            ...
# 106      Stanley Butler        26.764261
# 107     Lassiter Basket        26.238801
# 108     Willie Williams        26.727757
# 109     Nancy Woodhouse        29.320071
# 110   Elizabeth Milburn        27.325133
#
#                                           openingHours specialNotes
# 0      {'monday': {'open': '09:00', 'close': '12:00'}}
# 1    {'wednesday': {'open': '11:00', 'close': '13:0...
# 2    {'wednesday': {'open': '12:00', 'close': '18:0...
# 3     {'tuesday': {'open': '11:00', 'close': '13:00'}}
# 4    {'thursday': {'open': '11:00', 'close': '16:00'}}
# ..                                                 ...          ...
# 106  {'tuesday': {'open': '10:00', 'close': '12:00'...
# 107   {'tuesday': {'open': '15:00', 'close': '19:00'}}
# 108  {'saturday': {'open': '10:00', 'close': '12:00'}}
# 109  {'thursday': {'open': '11:00', 'close': '13:00'}}
# 110    {'sunday': {'open': '09:30', 'close': '12:00'}}
#
# [111 rows x 13 columns]

# %%
df1.to_json('output.json', orient='records', indent=2)
